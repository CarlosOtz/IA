# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosOtz/IA/blob/main/Examen_Medio_Curso_IA_Carlos_Ortiz_1849283.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Carlos Iván Ortiz Galván 1849283 Examen Medio Curso IA Jueves N4

# %% [markdown]
# EJERCICIO 1

# %% [markdown]
# Remueva los números pares de la lista:
#    ex_lista = [10, 15, 17, 21, 22, 34, 37, 40, 45, 52, 66, 68, 81, 84, 91, 94, 102, 105, 109]
# - Imprima la lista después de remover los números pares.

# %%
#DATOS
lista = [10, 15, 17, 21, 22, 34, 37, 40, 45, 52, 66, 68, 81, 84, 91, 94, 102, 105, 109]
#PROCESO
for x in lista: 
  if x % 2 != 0:
    print(x)
# Out:
# 15
# 17
# 21
# 37
# 45
# 81
# 91
# 105
# 109

# %% [markdown]
# EJERCICIO 2

# %% [markdown]
# Pregunte al usuario por sus 5 películas favoritas (dato tipo string), empezando por la mas favorita y terminando en la posición 5 con la menos favorita.
# - Almacene estos datos en una lista.
# - Por último, iterar sobre la lista generada para imprimir 5 oraciones (1 con cada título de película) que digan: "La película [TÍTULO DE PELÍCULA] está en la posición [índice+1] de mi top 5".
#       . TÍTULO DE PELÍCULA: corresponde a los nombres almacenados previamente en su lista.
#       . Recordatorio: Índice es la posición de un elemento dentro de una lista.

# %%
#DATOS 
print("Indique sus 5 peliculas favoritas siendo la 1 la más favorita y la 5 la menos")
a = str (input("1."))
b = str (input("2."))
c = str (input("3."))
d = str (input("4."))
e = str (input("5."))
#LISTA
lista = [a, b, c, d, e]
for i, _ in enumerate(lista):
    print("La pelicula {1} está en la posición {0} de mi top 5 ".format(i+1,lista[i]))
# Out:
# Indique sus 5 peliculas favoritas siendo la 1 la más favorita y la 5 la menos
# 1.Como entrenar a su dragón
# 2.Harry Potter
# 3.Spiderman
# 4.Super escuela de héroes
# 5.Miedo en lo profundo
# La pelicula Como entrenar a su dragón está en la posición 1 de mi top 5
# La pelicula Harry Potter  está en la posición 2 de mi top 5
# La pelicula Spiderman está en la posición 3 de mi top 5
# La pelicula Super escuela de héroes está en la posición 4 de mi top 5
# La pelicula Miedo en lo profundo  está en la posición 5 de mi top 5
